# %% [markdown]
# **Aula 02 - Importação**

# %% [markdown]
# # Nova seção

# %%
import pandas as pd

# %%
df_principal = pd.read_excel("/content/Imersão Python - Tabela de ações-26032024.xlsx",sheet_name="Principal")

# %%
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Variação %  \
# 0  USIM5 2024-01-26         9.50          5.20      0.0520
# 1  CMIN3 2024-01-26         6.82          2.40      0.0240
# 2  PETR3 2024-01-26        41.96          2.19      0.0219
# 3  SUZB3 2024-01-26        52.91          2.04      0.0204
# 4  CPFE3 2024-01-26        37.10          2.03      0.0203
# 5  PRIO3 2024-01-26        45.69          1.98      0.0198
# 6  PETR4 2024-01-26        39.96          1.73      0.0173
# 7  VALE3 2024-01-26        69.50          1.66      0.0166
# 8  MULT3 2024-01-26        28.19          1.58      0.0158
# 9  ITUB4 2024-01-26        32.81          1.48      0.0148
#
#    Variação Inicial (r$)   Qtd ações    Variação $ Resultado Nome da Empresa  \
# 0               9.030418   515117391  2.418897e+08     Subiu        Usiminas
# 1               6.660156  1110559345  1.775160e+08     Subiu   CSN Mineração
# 2              41.060769  2379877655  2.140059e+09     Subiu       Petrobras
# ...

# %%
df_total_acoes = pd.read_excel("/content/Imersão Python - Tabela de ações-26032024.xlsx",sheet_name="Total_de_acoes")
df_total_acoes.head(10)
# Out:
#   Código  Qtde. Teórica
# 0  RRRP3   2.356656e+08
# 1  ALOS3   5.326166e+08
# 2  ALPA4   1.767340e+08
# 3  ABEV3   4.394246e+09
# 4  ARZZ3   6.230589e+07
# 5  ASAI3   1.349218e+09
# 6  AZUL4   3.275937e+08
# 7  B3SA3   5.602790e+09
# 8  BBSE3   6.717508e+08
# 9  BBDC3   1.500729e+09

# %%
df_Ticker = pd.read_excel("/content/Imersão Python - Tabela de ações-26032024.xlsx",sheet_name="Ticker")
df_Ticker.head(10)
# Out:
#   Ticker            Nome
# 0  MGLU3  Magazine Luiza
# 1  HAPV3         Hapvida
# 2  PETR4       Petrobras
# 3  B3SA3              B3
# 4  USIM5        Usiminas
# 5  CVCB3             CVC
# 6  CIEL3           Cielo
# 7  VALE3            Vale
# 8  GOLL4             GOL
# 9  BBDC4  Banco Bradesco

# %%
df_ChatGPT = pd.read_excel("/content/Imersão Python - Tabela de ações-26032024.xlsx",sheet_name="ChatGPT")
df_ChatGPT.head(10)
# Out:
#     Nome Empresa                Segmento  Idade
# 0       Usiminas              Siderurgia     59
# 1  CSN Mineração               Mineração     75
# 2      Petrobras          Petróleo e Gás     69
# 3         Suzano        Papel e Celulose     98
# 4   CPFL Energia                 Energia     24
# 5       PetroRio          Petróleo e Gás      9
# 6      Petrobras          Petróleo e Gás     69
# 7           Vale               Mineração     79
# 8      Multiplan        Shopping Centers     51
# 9  Itaú Unibanco  Instituição Financeira     13
